# %%
import sys
from pathlib import Path

root = Path.cwd().parent  # from notebooks/ → repo root
if str(root) not in sys.path:
    sys.path.append(str(root))

from src.kaggle_utils import download_competition

data_dir = download_competition("titanic")
data_dir
# Out:
# PosixPath('data/raw/titanic')

# %%
Path.cwd().parent
# Out:
# PosixPath('/Users/boris.tsarev/MyProjects/kaggle-competitions')
